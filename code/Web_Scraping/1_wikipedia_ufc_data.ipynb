# %% [markdown]
# # **Scraping UFC Fight Outcomes and List of Events From Wikipedia**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import urllib.request as urllib2

# %% [markdown]
# ### **Scrape List of All UFC Cards From Wikipedia**

# %%
# pull list of past ufc events from wikipedia
url = "https://en.wikipedia.org/wiki/List_of_UFC_events"
page = requests.get(url)
soup = BeautifulSoup(page.text, 'lxml')
rows = soup.find('table', id="Past_events").find_all('tr')
columns = [x.text.strip() for x in rows[0].find_all('th')]
past_events = pd.DataFrame([[x.text.strip() for x in row.find_all('td')] for row in rows[1:]], columns = columns)
urls = []
for row in rows[1:]:
    s = row.find_all('td')
    if  len(s) >= 1 and getattr(s[1], 'a', None) != None:
       urls.append('https://en.wikipedia.org' + s[1].a['href'].strip())
    else:
        urls.append(None)
past_events['url'] = urls
past_events = past_events[past_events['Attendance'] != 'Cancelled']
past_events.sort_values('#', ascending = False, inplace = True)
past_events['Date'] = pd.to_datetime(past_events['Date'])
del past_events['Ref.']
past_events.to_csv("../../data/wikipedia_data/wikipedia_all_ufc_events.csv", index = False)

# %%
past_events.head()
# Out:
#      #                                       Event       Date  \
# 3  513           UFC Fight Night: Lee vs. Oliveira 2020-03-14
# 4  512                UFC 248: Adesanya vs. Romero 2020-03-07
# 5  511   UFC Fight Night: Benavidez vs. Figueiredo 2020-02-29
# 6  510          UFC Fight Night: Felder vs. Hooker 2020-02-23
# 7  509  UFC Fight Night: Anderson vs. Błachowicz 2 2020-02-15
#
#                    Venue                      Location Attendance  \
# 3  Ginásio Nilson Nelson              Brasília, Brazil          0
# 4         T-Mobile Arena       Las Vegas, Nevada, U.S.     15,077
# 5         Chartway Arena       Norfolk, Virginia, U.S.      7,098
# 6            Spark Arena         Auckland, New Zealand     10,025
# 7  Santa Ana Star Center  Rio Rancho, New Mexico, U.S.      6,449
#
#                                                  url
# 3  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 4              https://en.wikipedia.org/wiki/UFC_248
# 5  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 6  https://en.wikipedia.org/wiki/UFC_Fight_Night:...
# 7  https://en.wikipedia.org/wiki/UFC_Fight_Night:...

# %% [markdown]
# ### **Scrape List of All UFC Fight Outcomes For Each Card from Wikipedia**

# %%
dfs = []
for url in past_events['url']:
    if url != None:
        page = requests.get(url)
        soup = BeautifulSoup(page.text, 'lxml')
        
        if url == 'https://en.wikipedia.org/wiki/UFC_on_Fox:_Henderson_vs._Melendez':
            table = soup.find_all('table', class_ = 'toccolours')[2].tbody.find_all('tr')
        elif url == 'https://en.wikipedia.org/wiki/UFC_on_FX:_Belfort_vs._Bisping':
            table = soup.find_all('table', class_ = 'toccolours')[1].tbody.find_all('tr')
        else:
            table = soup.find('span', id = 'Results').parent.find_next_sibling().find('tbody').find_all('tr')
            
        card_type = table[0].find('th').text.strip()
        allrows = []
        for row in table[2:]:
            card_type_holder = row.find_all('th')
            if len(card_type_holder) == 1:
                card_type =  card_type_holder[0].text.strip()
                continue
            elif len(card_type_holder) > 0 and card_type_holder[0].text.strip().lower() == 'weight class':
                continue
            else:
                row_info = row.find_all('td')
                s = [x.text.strip() for x in row_info]
                if s[-1] != '':
                    ref = row_info[-1].a['href'].replace("#",'')
                    note = soup.find('li', id = ref).find('span', class_ = "reference-text").text
                    s[-1] = note
                s.append(card_type)
                try:
                    winner_link = "https://en.wikipedia.org" + row_info[1].a['href']
                except:
                    winner_link = ''
                try:
                    loser_link = "https://en.wikipedia.org" + row_info[3].a['href']
                except:
                    loser_link = ''
                s.append(winner_link)
                s.append(loser_link)
                allrows.append(s)
                

        df = pd.DataFrame(allrows, columns = ['WeightClass', 'Winner', 'Outcome', 'Loser', 'Method', 'Round', 'Time', 'Notes', 'Card', 'Winner_url', 'Loser_url'])
        df['wiki_url'] =url
        df['event_order'] = 1 + np.arange(df.shape[0]) 
        dfs.append(df)

# %% [markdown]
# ## Clean Up The Data

# %%
all_fights = pd.concat(dfs)
print(all_fights.Outcome.value_counts())
all_fights.Outcome = all_fights.Outcome.str.replace('.', '')
print(all_fights.Outcome.value_counts())

sub = all_fights.Method.str.contains(pat = '(?i)sub') 
knockout = all_fights.Method.str.contains(pat = '(?i)ko') 
unam_decision = all_fights.Method.str.contains(pat = '(?i)dec') & all_fights.Method.str.contains(pat = '(?i)(unanimous|majority)')
split_decision = all_fights.Method.str.contains(pat = '(?i)dec') & all_fights.Method.str.contains(pat = '(?i)split')
outcomes = pd.concat([sub, knockout, unam_decision, split_decision], axis=1)
display(all_fights.loc[outcomes.apply("sum", axis = 1) > 1, :])
sub[knockout] = False
outcomes = pd.concat([sub, knockout, unam_decision, split_decision], axis=1)
print(sum(outcomes.apply("sum", axis = 1) > 1))

all_fights.loc[sub, 'Method_Cleaned'] = "Sub"
all_fights.loc[knockout, 'Method_Cleaned'] = "KO"
all_fights.loc[unam_decision, 'Method_Cleaned'] = "Unanimous Decision"
all_fights.loc[split_decision, 'Method_Cleaned'] = "Split Decision"
print(all_fights.Method_Cleaned.value_counts(dropna= False))
display(all_fights.loc[(all_fights.Outcome == 'def') & (all_fights.Method_Cleaned.isna()), :])
# Out:
# def.    5359
# def      101
# vs.       91
# vs         2
# Name: Outcome, dtype: int64
# def    5460
# vs       93
# Name: Outcome, dtype: int64
#      WeightClass          Winner Outcome              Loser  \
# 11  Welterweight     Alex Morono     def          Zak Ottow
# 7   Bantamweight     Ricky Simon     def  Merab Dvalishvili
# 2   Middleweight       Joe Slick     def      Jason DeLucia
# 1    Heavyweight  Gary Goodridge     def      Andre Roberts
#
#                                         Method Round  Time Notes  \
# 11                  TKO (Submission to elbows)     1  3:34
# 7                   TKO (technical submission)     3  5:00
# 2   TKO (verbal submission due to knee injury)     1  1:28
# 1                  TKO (submission to punches)        0:42
#
#                                Card  \
# 11         Preliminary Card (ESPN+)
# 7   Preliminary card (Fox Sports 1)
# 2                         Main Card
# 1                         Main Card
#
#                                       Winner_url  \
# 11     https://en.wikipedia.org/wiki/Alex_Morono
# 7      https://en.wikipedia.org/wiki/Ricky_Simon
# 2        https://en.wikipedia.org/wiki/Joe_Slick
# 1   https://en.wikipedia.org/wiki/Gary_Goodridge
#
#                                             Loser_url  \
# 11            https://en.wikipedia.org/wiki/Zak_Ottow
# 7     https://en.wikipedia.org/wiki/Merab_Dvalishvili
# 2         https://en.wikipedia.org/wiki/Jason_DeLucia
# 1   https://en.wikipedia.org/wiki/Andre_Roberts_(M...
#
#                                              wiki_url  event_order
# 11  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           12
# 7   https://en.wikipedia.org/wiki/UFC_Fight_Night:...            8
# 2                https://en.wikipedia.org/wiki/UFC_23            3
# 1                https://en.wikipedia.org/wiki/UFC_19            2
# 0
# Unanimous Decision    1931
# KO                    1801
# Sub                   1191
# Split Decision         515
# NaN                    115
# Name: Method_Cleaned, dtype: int64
#          WeightClass             Winner Outcome              Loser  \
# 1       Welterweight      Diego Sanchez     def     Michel Pereira
# 3        Lightweight        Brok Weaver     def      Kazula Vargas
# 1        Heavyweight      Allen Crowder     def         Greg Hardy
# 8       Middleweight      C.B. Dollaway     def     Hector Lombard
# 6        Heavyweight       Mark Godbeer     def        Walt Harris
# 6        Lightweight      Abel Trujillo     def      Gleison Tibau
# 9       Middleweight          Joe Riggs     def      Ron Stallings
# 2       Welterweight    Kiichi Kunimoto     def     Luiz Dutra Jr.
# 5      Featherweight    Akira Corassani     def      Maximo Blanco
# 5       Middleweight       Patrick Côté     def     Alessio Sakara
# 3       Welterweight       Carlo Prater     def        Erick Silva
# 9       Welterweight     Matthew Riddle     def          Greg Soto
# 1  Light Heavyweight        Matt Hamill     def          Jon Jones
# 5  Light Heavyweight        James Irvin     def          Luiz Cane
# 5  Light Heavyweight       Thiago Silva     def        James Irvin
# 4        Heavyweight          Frank Mir     def           Wes Sims
# 5  Light Heavyweight      Matt Lindland     def    Ricardo Almeida
# 3       Middleweight     Amaury Bitetti     def       Alex Andrade
# 4        Heavyweight    Tsuyoshi Kosaka     def      Pete Williams
# 0        Heavyweight      Randy Couture     def  Maurice Smith (c)
# 5        Heavyweight        Tank Abbott     def          Yoji Anjo
# 2        Lightweight  Yoshiki Takahashi     def      Wallid Ismail
#
#                                          Method Round   Time  \
# 1                             DQ (illegal knee)     3   3:09
# 3                             DQ (illegal knee)     1   4:02
# 1                             DQ (illegal knee)     2   2:28
# 8                          DQ (illegal punches)     1   5:00
# 6                        DQ (illegal head kick)     1   4:29
# 6                 Disqualification (overturned)     1   1:45
# 9             Disqualification (illegal upkick)     2   2:28
# 2             Disqualification (illegal elbows)     1   2:57
# 5               Disqualification (illegal knee)     1   0:25
# 5    Disqualification (punches to back of head)     1   1:26
# 3       DQ (punches and elbows to back of head)     1   0:29
# 9             Disqualification (illegal upkick)     3   1:30
# 1                  DQ (illegal downward elbows)     1   4:14
# 5               Disqualification (illegal knee)     1   1:51
# 5                     Referee Stoppage (injury)     1   1:06
# 4  Disqualification (kicking a downed opponent)     1   2:55
# 5                           DQ (repeated fouls)     3   4:21
# 3         Disqualification (kicking with shoes)     2   0:43
# 4                                      Decision        15:00
# 0                                      Decision     1  21:00
# 5                                      Decision     1  15:00
# 2                                      Decision        15:00
#
#                                                Notes  \
# 1
# 3
# 1
# 8  Lombard was disqualified after hitting Dollawa...
# 6  Harris was disqualified for hitting Godbeer wi...
# 6  Originally a technical submission (rear-naked ...
# 9
# 2
# 5
# 5
# 3
# 9
# 1
# 5
# 5
# 4
# 5
# 3  UFC rules banned kicking while wearing shoes. ...
# 4
# 0   Couture defeated Smith to become the new UFC ...
# 5   Abbott was unable to continue in the tourname...
# 2   Takahashi broke his hand during the bout, and...
#
#                                 Card  \
# 1                  Main card (ESPN+)
# 3                  Main card (ESPN+)
# 1                  Main Card (ESPN+)
# 8    Preliminary Card (Fox Sports 1)
# 6    Preliminary Card (Fox Sports 1)
# 6    Preliminary Card (Fox Sports 1)
# 9  Preliminary Card (UFC Fight Pass)
# 2         Main Card (UFC Fight Pass)
# 5    Preliminary card (Fox Sports 1)
# 5              Preliminary Card (FX)
# 3                          Main card
# 9                   Preliminary card
# 1                          Main card
# 5                   Preliminary card
# 5                   Preliminary card
# 4                          Main Card
# 5                          Main Card
# 3                          Main Card
# 4                          Main Card
# 0           Heavyweight Championship
# 5  Heavyweight Tournament Semifinals
# 2             Lightweight Semifinals
#
#                                           Winner_url  \
# 1        https://en.wikipedia.org/wiki/Diego_Sanchez
# 3
# 1
# 8        https://en.wikipedia.org/wiki/C.B._Dollaway
# 6         https://en.wikipedia.org/wiki/Mark_Godbeer
# 6        https://en.wikipedia.org/wiki/Abel_Trujillo
# 9            https://en.wikipedia.org/wiki/Joe_Riggs
# 2      https://en.wikipedia.org/wiki/Kiichi_Kunimoto
# 5      https://en.wikipedia.org/wiki/Akira_Corassani
# 5  https://en.wikipedia.org/wiki/Patrick_C%C3%B4t...
# 3         https://en.wikipedia.org/wiki/Carlo_Prater
# 9       https://en.wikipedia.org/wiki/Matthew_Riddle
# 1          https://en.wikipedia.org/wiki/Matt_Hamill
# 5  https://en.wikipedia.org/wiki/James_Irvin_(fig...
# 5  https://en.wikipedia.org/wiki/Thiago_Silva_(fi...
# 4            https://en.wikipedia.org/wiki/Frank_Mir
# 5        https://en.wikipedia.org/wiki/Matt_Lindland
# 3       https://en.wikipedia.org/wiki/Amaury_Bitetti
# 4      https://en.wikipedia.org/wiki/Tsuyoshi_Kosaka
# 0        https://en.wikipedia.org/wiki/Randy_Couture
# 5          https://en.wikipedia.org/wiki/Tank_Abbott
# 2      https://en.wikipedia.org/wiki/Kazuo_Takahashi
#
#                                            Loser_url  \
# 1
# 3
# 1           https://en.wikipedia.org/wiki/Greg_Hardy
# 8       https://en.wikipedia.org/wiki/Hector_Lombard
# 6  https://en.wikipedia.org/wiki/Walt_Harris_(fig...
# 6        https://en.wikipedia.org/wiki/Gleison_Tibau
# 9        https://en.wikipedia.org/wiki/Ron_Stallings
# 2
# 5        https://en.wikipedia.org/wiki/Maximo_Blanco
# 5       https://en.wikipedia.org/wiki/Alessio_Sakara
# 3          https://en.wikipedia.org/wiki/Erick_Silva
# 9            https://en.wikipedia.org/wiki/Greg_Soto
# 1            https://en.wikipedia.org/wiki/Jon_Jones
# 5            https://en.wikipedia.org/wiki/Luiz_Cane
# 5  https://en.wikipedia.org/wiki/James_Irvin_(fig...
# 4   https://en.wikipedia.org/wiki/Wes_Sims_(fighter)
# 5      https://en.wikipedia.org/wiki/Ricardo_Almeida
# 3  https://en.wikipedia.org/wiki/Alex_Andrade_(fi...
# 4  https://en.wikipedia.org/wiki/Pete_Williams_(m...
# 0  https://en.wikipedia.org/wiki/Maurice_Smith_(k...
# 5            https://en.wikipedia.org/wiki/Yoji_Anjo
# 2        https://en.wikipedia.org/wiki/Wallid_Ismail
#
#                                             wiki_url  event_order  \
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            2
# 3  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            4
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            2
# 8              https://en.wikipedia.org/wiki/UFC_222            9
# 6              https://en.wikipedia.org/wiki/UFC_217            7
# 6  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            7
# 9              https://en.wikipedia.org/wiki/UFC_191           10
# 2  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            3
# 5  https://en.wikipedia.org/wiki/The_Ultimate_Fig...            6
# 5              https://en.wikipedia.org/wiki/UFC_154            6
# 3              https://en.wikipedia.org/wiki/UFC_142            4
# 9              https://en.wikipedia.org/wiki/UFC_111           10
# 1  https://en.wikipedia.org/wiki/The_Ultimate_Fig...            2
# 5               https://en.wikipedia.org/wiki/UFC_79            6
# 5               https://en.wikipedia.org/wiki/UFC_71            6
# 4               https://en.wikipedia.org/wiki/UFC_43            5
# 5               https://en.wikipedia.org/wiki/UFC_31            6
# 3               https://en.wikipedia.org/wiki/UFC_26            4
# 4           https://en.wikipedia.org/wiki/UFC_Brazil            5
# 0  https://en.wikipedia.org/wiki/UFC_Japan:_Ultim...            1
# 5  https://en.wikipedia.org/wiki/UFC_Japan:_Ultim...            6
# 2               https://en.wikipedia.org/wiki/UFC_12            3
#
#   Method_Cleaned
# 1            NaN
# 3            NaN
# 1            NaN
# 8            NaN
# 6            NaN
# 6            NaN
# 9            NaN
# 2            NaN
# 5            NaN
# 5            NaN
# 3            NaN
# 9            NaN
# 1            NaN
# 5            NaN
# 5            NaN
# 4            NaN
# 5            NaN
# 3            NaN
# 4            NaN
# 0            NaN
# 5            NaN
# 2            NaN

# %%
print(all_fights.Card.value_counts(dropna= False))
main = all_fights.Card.str.contains('(?i)main')
prelim = all_fights.Card.str.contains('(?i)prelim')
print(sum(main & prelim))
all_fights.loc[main, 'Card_Cleaned'] = "Main Event"
all_fights.loc[prelim, 'Card_Cleaned'] = "Prelim"
print(all_fights.Card_Cleaned.value_counts(dropna= False))
# Out:
# Main Card                                   776
# Preliminary card                            487
# Preliminary Card (UFC Fight Pass)           443
# Main Card (Fox Sports 1)                    425
# Preliminary Card (Fox Sports 1)             423
#                                            ...
# UFC Japan Middleweight Tournament Finals      1
# Heavyweight Tournament Final                  1
# Middleweight Finals                           1
# Heavyweight Superfight                        1
# UFC Heavyweight Championship                  1
# Name: Card, Length: 115, dtype: int64
# 0
# Prelim        2865
# Main Event    2437
# NaN            251
# Name: Card_Cleaned, dtype: int64

# %%
# Standardize fighter names and determine if champion or interim champion is fighting

cleaner_winner = all_fights['Winner'].map(lambda x: x.split('(', 1))
cleaner_winner = cleaner_winner.map(lambda x: [x[0].strip(), x[1].strip().lower()] if len(x) > 1 else [x[0].strip()])
clean_winner = cleaner_winner.map(lambda x: x[0])

cleaner_loser = all_fights['Loser'].map(lambda x: x.split('(', 1))
cleaner_loser= cleaner_loser.map(lambda x: [x[0].strip(), x[1].strip().lower()] if len(x) > 1 else [x[0].strip()])
clean_loser = cleaner_loser.map(lambda x: x[0])

champ = cleaner_winner.map(lambda x: x[0] if len(x) > 1 and x[1] == 'c)' else '')
champ = np.where(champ == '', cleaner_loser.map(lambda x: x[0] if len(x) > 1 and x[1] == 'c)' else ''), champ)
interim_champ = cleaner_winner.map(lambda x: x[0] if len(x) > 1 and x[1] == 'ic)' else '')
interim_champ = np.where(interim_champ  == '', cleaner_loser.map(lambda x: x[0] if len(x) > 1 and x[1] == 'ic)' else ''), interim_champ)


all_fights['Winner_Cleaned'] = clean_winner
all_fights['Loser_Cleaned'] = clean_loser
all_fights['Champion'] = champ
all_fights['Interim_Champion'] = interim_champ
display(all_fights.head())
# Out:
#                WeightClass              Winner Outcome           Loser  \
# 0  Catchweight (158.5 lbs)    Charles Oliveira     def       Kevin Lee
# 1             Welterweight       Gilbert Burns     def     Demian Maia
# 2              Lightweight      Renato Moicano     def  Damir Hadžović
# 3        Light Heavyweight       Nikita Krylov     def   Johnny Walker
# 4              Lightweight  Francisco Trinaldo     def   John Makdessi
#
#                                        Method Round  Time Notes  \
# 0               Submission (guillotine choke)     3  0:28
# 1                               TKO (punches)     1  2:34
# 2               Submission (rear-naked choke)     1  0:44
# 3  Decision (unanimous) (30–27, 29–28, 29–28)     3  5:00
# 4  Decision (unanimous) (30–27, 30–27, 29–28)     3  5:00
#
#                      Card                                         Winner_url  \
# 0  Main card (ESPN+/ESPN)     https://en.wikipedia.org/wiki/Charles_Oliveira
# 1  Main card (ESPN+/ESPN)  https://en.wikipedia.org/wiki/Gilbert_Burns_(f...
# 2  Main card (ESPN+/ESPN)       https://en.wikipedia.org/wiki/Renato_Moicano
# 3  Main card (ESPN+/ESPN)        https://en.wikipedia.org/wiki/Nikita_Krylov
# 4  Main card (ESPN+/ESPN)   https://en.wikipedia.org/wiki/Francisco_Trinaldo
#
#                                            Loser_url  \
# 0  https://en.wikipedia.org/wiki/Kevin_Lee_(fighter)
# 1          https://en.wikipedia.org/wiki/Demian_Maia
# 2  https://en.wikipedia.org/wiki/Damir_Had%C5%BEo...
# 3  https://en.wikipedia.org/wiki/Johnny_Walker_(f...
# 4        https://en.wikipedia.org/wiki/John_Makdessi
#
#                                             wiki_url  event_order  \
# 0  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            1
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            2
# 2  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            3
# 3  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            4
# 4  https://en.wikipedia.org/wiki/UFC_Fight_Night:...            5
#
#        Method_Cleaned Card_Cleaned      Winner_Cleaned   Loser_Cleaned  \
# 0                 Sub   Main Event    Charles Oliveira       Kevin Lee
# 1                  KO   Main Event       Gilbert Burns     Demian Maia
# 2                 Sub   Main Event      Renato Moicano  Damir Hadžović
# 3  Unanimous Decision   Main Event       Nikita Krylov   Johnny Walker
# 4  Unanimous Decision   Main Event  Francisco Trinaldo   John Makdessi
#
#   Champion Interim_Champion
# 0
# 1
# 2
# 3
# 4

# %%
all_fights.to_csv("../../data/wikipedia_data/wikipedia_all_ufc_fight_outcomes.csv", index = False)
