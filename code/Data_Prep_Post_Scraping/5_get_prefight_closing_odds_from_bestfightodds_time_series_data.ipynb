# %% [markdown]
# # Get Closing Odds From Odds Time Series

# %% [markdown]
# Bestfightodds periodically scrapes the various betting sites and posts new odds only when they are updated. Because some betting sites off live betting whereas others don't, the final quoted odds accross sites might not be comparable. As such, I pull pre-fight closing odds as of 16 hours before the final time odds are posted for the UFC card/event by any site. This should closely approximate betting just a few hours before the event starts.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
pd.set_option('display.max_columns', 500)
from zipfile import ZipFile
from datetime import timedelta

# %%
# load all odds. Since I'm just creating a mapping I only need one row per fight
zip_file = ZipFile('../../data/bestfightodds_data/straight_bets.zip')
dfs = [pd.read_csv(zip_file.open(text_file.filename)) for text_file in zip_file.infolist() 
       if text_file.filename.endswith('.csv')]
df = pd.concat(dfs, sort = False)
del dfs

# get all fights that actually happened and their outcomes
actualbets = pd.read_csv('../../data/bestfightodds_data/outcome_mapping_bfodds_to_wiki.csv')

df = pd.merge(df, actualbets[['fighter1', 'fighter2', 'fight_odds_url']],
             left_on = ['fighter1', 'fighter2', 'url'],
             right_on = ['fighter1', 'fighter2', 'fight_odds_url']
             )
df['Date'] = pd.to_datetime(df['dates'], unit = 'ms')
del df['url']
display(df.head())
# Out:
#                Bet betsite          dates  odds         fighter1  \
# 0  Fabio Maldonado  5Dimes  1400173028000   335  Fabio Maldonado
# 1  Fabio Maldonado  5Dimes  1400176811000   420  Fabio Maldonado
# 2  Fabio Maldonado  5Dimes  1400635445000   350  Fabio Maldonado
# 3  Fabio Maldonado  5Dimes  1401040266000   400  Fabio Maldonado
# 4  Fabio Maldonado  5Dimes  1401472446000   450  Fabio Maldonado
#
#        fighter2 class                                     fight_odds_url  \
# 0  Stipe Miocic  even  https://www.bestfightodds.com/events/ufc-the-u...
# 1  Stipe Miocic  even  https://www.bestfightodds.com/events/ufc-the-u...
# 2  Stipe Miocic  even  https://www.bestfightodds.com/events/ufc-the-u...
# 3  Stipe Miocic  even  https://www.bestfightodds.com/events/ufc-the-u...
# 4  Stipe Miocic  even  https://www.bestfightodds.com/events/ufc-the-u...
#
#                  Date
# 0 2014-05-15 16:57:08
# 1 2014-05-15 18:00:11
# 2 2014-05-21 01:24:05
# 3 2014-05-25 17:51:06
# 4 2014-05-30 17:54:06

# %%
# get time odds quotesd will be taken from. 12 hours before final odd quoted for a UFC card by any site
df['odds_close_time'] = df.groupby('fight_odds_url')['Date'].transform("max") - timedelta(hours = 16)

# confirm all sites had odds quoted prior to this time and not too far behind it (to avoid weird anomalies where maybe 
#                                                                                 bets stopped being offered prior to the time)
df['recent_odds_window']= df['odds_close_time'] - timedelta(days = 7)
has_odds = df.groupby(['fight_odds_url', 'betsite', 'fighter1', 'fighter2', 'Bet']).apply(lambda x: (((x['Date'] <= x['odds_close_time'])   
                                                                     & (x['Date'] >= x['recent_odds_window'])
                                                                                         ).any())).reset_index()
has_odds.rename(columns = {0:'has_bet'}, inplace = True)

# %%
sum(has_odds.has_bet)/has_odds.shape[0]
# Out:
# 0.9684448015823959

# %%
# get latest price quote prior to odds close time 12 hr after last card quote
# this is my definition of pre-fight odds.
# to avoid garbage data I require that the quote be no more than a week before the fight
# maybe sites stopped offering bets at some point if their quote hasn't 
# updated

out = df[(df['Date'] <= df['odds_close_time']) & 
         (df['Date'] >= df['recent_odds_window'])]
byval = ['fighter1', 'fighter2', 'fight_odds_url', 'Bet', 'betsite', 'Date']
out = out.sort_values(byval).groupby(byval[0:-1]).nth(-1).reset_index()

# %%
hasbothsides = out.groupby(['fighter1', 'fighter2', 'fight_odds_url', 'betsite']).size().reset_index()
hasbothsides.rename(columns = {0:'size'}, inplace = True)
print(sum(hasbothsides['size'] ==2)/hasbothsides.shape[0])
print(out.shape)
out['bothsidessize'] = out.groupby(['fighter1', 'fighter2', 'fight_odds_url', 'betsite'])['betsite'].transform(np.size)
out = out[out['bothsidessize'] == 2]
print(out.shape)
del out['bothsidessize']
# Out:
# 0.9997659972770592
# (94005, 11)
# (93994, 12)

# %%
keepcol = ['fighter1', 'fighter2', 'fight_odds_url',  'Bet']

finaldf1 = out[keepcol+['odds', 'betsite']].pivot_table(values = ['odds'], columns = ['betsite'], 
                    index = keepcol,
                    aggfunc='first').reset_index()
finaldf1.columns = [a if b == '' else b for (a, b) in finaldf1.columns]

# %%
def nansumwrapper(a, **kwargs):
    if np.isnan(a).all():
        return np.nan
    else:
        return np.nansum(a, **kwargs)

finaldf1.rename({'William\xa0H.':'William_H', 'SportsInt.':'SportsInt'}, inplace = True, axis = 1)
betting_sites= ['5Dimes','BetDSI','BookMaker','SportBet','Bet365','Bovada', 
                'Sportsbook','William_H','Pinnacle','SportsInt','BetOnline','Intertops']
for col in betting_sites:
    finaldf1[col] = pd.to_numeric(finaldf1[col])
    finaldf1[col] = np.where(finaldf1[col] > 0, 1.0 + finaldf1[col]/100.0, 1.0 - 100.0 / finaldf1[col])
    finaldf1[col+"_vig"] = finaldf1.groupby(['fighter1','fighter2', 'fight_odds_url'])[col].transform(lambda x: nansumwrapper(x**-1) -1.0)
finaldf1['meanodds'] = finaldf1[betting_sites].mean(axis=1)

# %%
display(finaldf1.head())
print(sum(finaldf1[[x+"_vig" for x in betting_sites]].apply(lambda x: (x < 0).any(), axis = 1)))
finaldf1[finaldf1[[x+"_vig" for x in betting_sites]].apply(lambda x: (x < 0).any(), axis = 1)].to_csv("redo.csv")
# Out:
#          fighter1       fighter2  \
# 0      Aalon Cruz  Spike Carlyle
# 1      Aalon Cruz  Spike Carlyle
# 2  Aaron Phillips     Matt Hobar
# 3  Aaron Phillips     Matt Hobar
# 4  Aaron Phillips    Sam Sicilia
#
#                                       fight_odds_url             Bet  \
# 0  https://www.bestfightodds.com/events/ufc-on-es...      Aalon Cruz
# 1  https://www.bestfightodds.com/events/ufc-on-es...   Spike Carlyle
# 2  https://www.bestfightodds.com/events/ufc-fight...  Aaron Phillips
# 3  https://www.bestfightodds.com/events/ufc-fight...      Matt Hobar
# 4  https://www.bestfightodds.com/events/ufc-173-b...  Aaron Phillips
#
#      5Dimes    Bet365    BetDSI  BetOnline  BookMaker    Bovada  Intertops  \
# 0  1.540541  1.571429  1.510204   1.540541    1.50000  1.500000   1.526316
# 1  2.700000  2.500000  2.630000   2.600000    2.58000  2.600000   2.500000
# 2  2.880000       NaN  2.800000   2.800000    2.80000  2.750000        NaN
# 3  1.487805       NaN  1.476190   1.476190    1.47619  1.444444        NaN
# 4  2.300000       NaN  2.250000   2.300000    2.25000  2.250000        NaN
#
#    Pinnacle  SportBet  SportsInt  Sportsbook  William_H  meanodds  5Dimes_vig  \
# 0  1.515464  1.537634   1.555556    1.540541        1.5  1.528185    0.019493
# 1  2.650000  2.690000   2.450000    2.500000        2.6  2.583333    0.019493
# 2  2.840000  2.830000   2.700000    2.800000        NaN  2.800000    0.019353
# 3  1.487805  1.476190   1.450450    1.444444        NaN  1.468857    0.019353
# 4  2.320000  2.280000   2.300000    2.300000        NaN  2.283333    0.018116
#
#    BetDSI_vig  BookMaker_vig  SportBet_vig  Bet365_vig  Bovada_vig  \
# 0    0.042390       0.054264      0.022097    0.036364    0.051282
# 1    0.042390       0.054264      0.022097    0.036364    0.051282
# 2    0.034562       0.034562      0.030776         NaN    0.055944
# 3    0.034562       0.034562      0.030776         NaN    0.055944
# 4    0.036281       0.036281      0.025373         NaN    0.052288
#
#    Sportsbook_vig  William_H_vig  Pinnacle_vig  SportsInt_vig  BetOnline_vig  \
# 0        0.049123       0.051282      0.037222       0.051020       0.033738
# 1        0.049123       0.051282      0.037222       0.051020       0.033738
# 2        0.049451            NaN      0.024244       0.059811       0.034562
# 3        0.049451            NaN      0.024244       0.059811       0.034562
# 4        0.050167            NaN      0.024530       0.055995       0.034783
#
#    Intertops_vig
# 0       0.055172
# 1       0.055172
# 2            NaN
# 3            NaN
# 4            NaN
# 32

# %%
finaldf2 = pd.merge(finaldf1, actualbets,
                    on = ['fighter1','fighter2', 'fight_odds_url'],
                   validate = "m:1")

finaldf2['bet_won'] = np.where((finaldf2['Bet'] == finaldf2['bestfightodds_winner']),
                              1,0)


display(finaldf2.head())
finaldf2.to_csv('../../data/datasets_for_analysis/final_datasets/odds_w_outcomes.csv', index = False)
# Out:
#          fighter1       fighter2  \
# 0      Aalon Cruz  Spike Carlyle
# 1      Aalon Cruz  Spike Carlyle
# 2  Aaron Phillips     Matt Hobar
# 3  Aaron Phillips     Matt Hobar
# 4  Aaron Phillips    Sam Sicilia
#
#                                       fight_odds_url             Bet  \
# 0  https://www.bestfightodds.com/events/ufc-on-es...      Aalon Cruz
# 1  https://www.bestfightodds.com/events/ufc-on-es...   Spike Carlyle
# 2  https://www.bestfightodds.com/events/ufc-fight...  Aaron Phillips
# 3  https://www.bestfightodds.com/events/ufc-fight...      Matt Hobar
# 4  https://www.bestfightodds.com/events/ufc-173-b...  Aaron Phillips
#
#      5Dimes    Bet365    BetDSI  BetOnline  BookMaker    Bovada  Intertops  \
# 0  1.540541  1.571429  1.510204   1.534759    1.50000  1.500000   1.526316
# 1  2.700000  2.500000  2.630000   2.620000    2.58000  2.600000   2.500000
# 2  2.880000       NaN  2.800000   2.800000    2.80000  2.750000        NaN
# 3  1.487805       NaN  1.476190   1.476190    1.47619  1.444444        NaN
# 4  2.300000       NaN  2.250000   2.300000    2.25000  2.300000        NaN
#
#    Pinnacle  SportBet  SportsInt  Sportsbook  William_H  meanodds  \
# 0  1.515464  1.537634   1.555556    1.540541        1.5  1.527704
# 1  2.650000  2.690000   2.400000    2.500000        2.6  2.580833
# 2  2.830000  2.830000   2.700000    2.800000        NaN  2.798889
# 3  1.490196  1.476190   1.450450    1.444444        NaN  1.469122
# 4  2.320000  2.280000   2.300000    2.300000        NaN  2.288889
#
#   Winner_Cleaned   Loser_Cleaned  \
# 0  Spike Carlyle      Aalon Cruz
# 1  Spike Carlyle      Aalon Cruz
# 2     Matt Hobar  Aaron Phillips
# 3     Matt Hobar  Aaron Phillips
# 4    Sam Sicilia  Aaron Phillips
#
#                                             wiki_url bestfightodds_winner  \
# 0  https://en.wikipedia.org/wiki/UFC_Fight_Night:...        Spike Carlyle
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...        Spike Carlyle
# 2  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           Matt Hobar
# 3  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           Matt Hobar
# 4              https://en.wikipedia.org/wiki/UFC_173          Sam Sicilia
#
#   bestfightodds_loser    WeightClass         Winner Outcome           Loser  \
# 0          Aalon Cruz  Featherweight  Spike Carlyle     def      Aalon Cruz
# 1          Aalon Cruz  Featherweight  Spike Carlyle     def      Aalon Cruz
# 2      Aaron Phillips   Bantamweight     Matt Hobar     def  Aaron Phillips
# 3      Aaron Phillips   Bantamweight     Matt Hobar     def  Aaron Phillips
# 4      Aaron Phillips  Featherweight    Sam Sicilia     def  Aaron Phillips
#
#                                        Method  Round  Time Notes  \
# 0                               TKO (punches)    1.0  1:25   NaN
# 1                               TKO (punches)    1.0  1:25   NaN
# 2  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
# 3  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
# 4  Decision (unanimous) (29–28, 29–28, 30–27)    3.0  5:00   NaN
#
#                                 Card  \
# 0           Preliminary card (ESPN+)
# 1           Preliminary card (ESPN+)
# 2    Preliminary card (Fox Sports 2)
# 3    Preliminary card (Fox Sports 2)
# 4  Preliminary card (UFC Fight Pass)
#
#                                   Winner_url Loser_url  event_order  \
# 0                                        NaN       NaN           11
# 1                                        NaN       NaN           11
# 2   https://en.wikipedia.org/wiki/Matt_Hobar       NaN            9
# 3   https://en.wikipedia.org/wiki/Matt_Hobar       NaN            9
# 4  https://en.wikipedia.org/wiki/Sam_Sicilia       NaN           11
#
#        Method_Cleaned Card_Cleaned Champion Interim_Champion   Card_Date    #  \
# 0                  KO       Prelim      NaN              NaN  2020-02-29  511
# 1                  KO       Prelim      NaN              NaN  2020-02-29  511
# 2  Unanimous Decision       Prelim      NaN              NaN  2014-08-23  287
# 3  Unanimous Decision       Prelim      NaN              NaN  2014-08-23  287
# 4  Unanimous Decision       Prelim      NaN              NaN  2014-05-24  273
#
#                                        Event  bet_won
# 0  UFC Fight Night: Benavidez vs. Figueiredo        0
# 1  UFC Fight Night: Benavidez vs. Figueiredo        1
# 2   UFC Fight Night: Henderson vs. dos Anjos        0
# 3   UFC Fight Night: Henderson vs. dos Anjos        1
# 4               UFC 173: Barão vs. Dillashaw        0

# %%
# create dataset with one row per fight
cols= ['5Dimes','BetDSI','BookMaker','SportBet','Bet365','Bovada', 
                'Sportsbook','William_H','Pinnacle',
       'SportsInt','BetOnline','Intertops', 'meanodds', 'fighter1',
      'fighter2', 'fight_odds_url']
winner = finaldf2[finaldf2.Bet == finaldf2.bestfightodds_winner]
loser = finaldf2.loc[finaldf2.Bet == finaldf2.bestfightodds_loser, cols]

onerowperfight = pd.merge(winner,loser, 
                          on = ['fighter1', 'fighter2', 'fight_odds_url'],
                          suffixes =('_win', '_lose'))
display(onerowperfight.head())
onerowperfight.to_csv('../../data/datasets_for_analysis/final_datasets/odds_w_outcomes_one_row_per_fight.csv', index = False)
# Out:
#          fighter1       fighter2  \
# 0      Aalon Cruz  Spike Carlyle
# 1  Aaron Phillips     Matt Hobar
# 2  Aaron Phillips    Sam Sicilia
# 3     Aaron Riley    Joe Brammer
# 4     Aaron Riley   Jorge Gurgel
#
#                                       fight_odds_url            Bet  \
# 0  https://www.bestfightodds.com/events/ufc-on-es...  Spike Carlyle
# 1  https://www.bestfightodds.com/events/ufc-fight...     Matt Hobar
# 2  https://www.bestfightodds.com/events/ufc-173-b...    Sam Sicilia
# 3  https://www.bestfightodds.com/events/ufc-114-j...    Aaron Riley
# 4  https://www.bestfightodds.com/events/ufc-91-co...    Aaron Riley
#
#    5Dimes_win  Bet365_win  BetDSI_win  BetOnline_win  BookMaker_win  \
# 0    2.700000         2.5    2.630000       2.620000       2.580000
# 1    1.487805         NaN    1.476190       1.476190       1.476190
# 2    1.714286         NaN    1.689655       1.666667       1.689655
# 3    1.526316         NaN         NaN            NaN       1.512821
# 4    2.100000         NaN         NaN            NaN       1.909091
#
#    Bovada_win  Intertops_win  Pinnacle_win  SportBet_win  SportsInt_win  \
# 0    2.600000            2.5      2.650000      2.690000       2.400000
# 1    1.444444            NaN      1.490196      1.476190       1.450450
# 2    1.625000            NaN      1.684932      1.704225       1.609756
# 3    1.540541            NaN      1.507614      1.526316            NaN
# 4    1.869565            NaN      2.170000      1.952381       2.000000
#
#    Sportsbook_win  William_H_win  meanodds_win Winner_Cleaned   Loser_Cleaned  \
# 0        2.500000            2.6      2.580833  Spike Carlyle      Aalon Cruz
# 1        1.444444            NaN      1.469122     Matt Hobar  Aaron Phillips
# 2        1.625000            NaN      1.667686    Sam Sicilia  Aaron Phillips
# 3        1.540541            NaN      1.525691    Aaron Riley     Joe Brammer
# 4        1.952381            NaN      1.993345    Aaron Riley    Jorge Gurgel
#
#                                             wiki_url bestfightodds_winner  \
# 0  https://en.wikipedia.org/wiki/UFC_Fight_Night:...        Spike Carlyle
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           Matt Hobar
# 2              https://en.wikipedia.org/wiki/UFC_173          Sam Sicilia
# 3              https://en.wikipedia.org/wiki/UFC_114          Aaron Riley
# 4               https://en.wikipedia.org/wiki/UFC_91          Aaron Riley
#
#   bestfightodds_loser    WeightClass         Winner Outcome           Loser  \
# 0          Aalon Cruz  Featherweight  Spike Carlyle     def      Aalon Cruz
# 1      Aaron Phillips   Bantamweight     Matt Hobar     def  Aaron Phillips
# 2      Aaron Phillips  Featherweight    Sam Sicilia     def  Aaron Phillips
# 3         Joe Brammer    Lightweight    Aaron Riley     def     Joe Brammer
# 4        Jorge Gurgel    Lightweight    Aaron Riley     def    Jorge Gurgel
#
#                                        Method  Round  Time Notes  \
# 0                               TKO (punches)    1.0  1:25   NaN
# 1  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
# 2  Decision (unanimous) (29–28, 29–28, 30–27)    3.0  5:00   NaN
# 3  Decision (unanimous) (30–27, 30–27, 30–27)    3.0  5:00   NaN
# 4  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
#
#                                 Card  \
# 0           Preliminary card (ESPN+)
# 1    Preliminary card (Fox Sports 2)
# 2  Preliminary card (UFC Fight Pass)
# 3                   Preliminary card
# 4                   Preliminary card
#
#                                   Winner_url  \
# 0                                        NaN
# 1   https://en.wikipedia.org/wiki/Matt_Hobar
# 2  https://en.wikipedia.org/wiki/Sam_Sicilia
# 3  https://en.wikipedia.org/wiki/Aaron_Riley
# 4  https://en.wikipedia.org/wiki/Aaron_Riley
#
#                                     Loser_url  event_order  \
# 0                                         NaN           11
# 1                                         NaN            9
# 2                                         NaN           11
# 3                                         NaN           10
# 4  https://en.wikipedia.org/wiki/Jorge_Gurgel            6
#
#        Method_Cleaned Card_Cleaned Champion Interim_Champion   Card_Date    #  \
# 0                  KO       Prelim      NaN              NaN  2020-02-29  511
# 1  Unanimous Decision       Prelim      NaN              NaN  2014-08-23  287
# 2  Unanimous Decision       Prelim      NaN              NaN  2014-05-24  273
# 3  Unanimous Decision       Prelim      NaN              NaN  2010-05-29  152
# 4  Unanimous Decision       Prelim      NaN              NaN  2008-11-15  119
#
#                                        Event  bet_won  5Dimes_lose  \
# 0  UFC Fight Night: Benavidez vs. Figueiredo        1     1.540541
# 1   UFC Fight Night: Henderson vs. dos Anjos        1     2.880000
# 2               UFC 173: Barão vs. Dillashaw        1     2.300000
# 3                 UFC 114: Rampage vs. Evans        1     2.650000
# 4                 UFC 91: Couture vs. Lesnar        1     1.769231
#
#    BetDSI_lose  BookMaker_lose  SportBet_lose  Bet365_lose  Bovada_lose  \
# 0     1.510204        1.500000       1.537634     1.571429     1.500000
# 1     2.800000        2.800000       2.830000          NaN     2.750000
# 2     2.250000        2.250000       2.280000          NaN     2.300000
# 3          NaN        2.550000       2.650000          NaN     2.550000
# 4          NaN        1.833333       1.800000          NaN     1.869565
#
#    Sportsbook_lose  William_H_lose  Pinnacle_lose  SportsInt_lose  \
# 0         1.540541             1.5       1.515464        1.555556
# 1         2.800000             NaN       2.830000        2.700000
# 2         2.300000             NaN       2.320000        2.300000
# 3         2.550000             NaN       2.770000             NaN
# 4         1.800000             NaN       1.787402        1.719424
#
#    BetOnline_lose  Intertops_lose  meanodds_lose
# 0        1.534759        1.526316       1.527704
# 1        2.800000             NaN       2.798889
# 2        2.300000             NaN       2.288889
# 3             NaN             NaN       2.620000
# 4             NaN             NaN       1.796994
