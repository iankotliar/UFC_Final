# %% [markdown]
# # Investigate Betting Strategies Based On Simple Rules For Estimating Fighter's Prob of Winning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
pd.set_option('display.max_columns', 500)
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy.random

# %%
bets = pd.read_csv('../../../data/datasets_for_analysis/final_datasets/odds_w_outcomes.csv')
bets['Card_Date'] = pd.to_datetime(bets['Card_Date'] )
bets['year'] = bets['Card_Date'].dt.year

# %%
print(str(bets.shape[0]/2)+ " "+
      'fights in the dataset from '+str(bets.year.min())+' to '+
     str(bets.year.max()))

print(bets.Outcome.value_counts())
bets = bets[bets.Outcome == 'def']

print(str(bets.shape[0]/2)+ " "+
      'fights in the dataset that did not result in a NC or draw from '+str(bets.year.min())+' to '+
     str(bets.year.max()))
display(bets.head())
# Out:
# 4702.0 fights in the dataset from 2008 to 2020
# def    9240
# vs      164
# Name: Outcome, dtype: int64
# 4620.0 fights in the dataset that did not result in a NC or draw from 2008 to 2020
#          fighter1       fighter2  \
# 0      Aalon Cruz  Spike Carlyle
# 1      Aalon Cruz  Spike Carlyle
# 2  Aaron Phillips     Matt Hobar
# 3  Aaron Phillips     Matt Hobar
# 4  Aaron Phillips    Sam Sicilia
#
#                                       fight_odds_url             Bet  \
# 0  https://www.bestfightodds.com/events/ufc-on-es...      Aalon Cruz
# 1  https://www.bestfightodds.com/events/ufc-on-es...   Spike Carlyle
# 2  https://www.bestfightodds.com/events/ufc-fight...  Aaron Phillips
# 3  https://www.bestfightodds.com/events/ufc-fight...      Matt Hobar
# 4  https://www.bestfightodds.com/events/ufc-173-b...  Aaron Phillips
#
#      5Dimes    Bet365    BetDSI  BetOnline  BookMaker    Bovada  Intertops  \
# 0  1.540541  1.571429  1.510204   1.540541    1.50000  1.500000   1.526316
# 1  2.700000  2.500000  2.630000   2.600000    2.58000  2.600000   2.500000
# 2  2.880000       NaN  2.800000   2.800000    2.80000  2.750000        NaN
# 3  1.487805       NaN  1.476190   1.476190    1.47619  1.444444        NaN
# 4  2.300000       NaN  2.250000   2.300000    2.25000  2.250000        NaN
#
#    Pinnacle  SportBet  SportsInt  Sportsbook  William_H  meanodds  5Dimes_vig  \
# 0  1.515464  1.537634   1.555556    1.540541        1.5  1.528185    0.019493
# 1  2.650000  2.690000   2.450000    2.500000        2.6  2.583333    0.019493
# 2  2.840000  2.830000   2.700000    2.800000        NaN  2.800000    0.019353
# 3  1.487805  1.476190   1.450450    1.444444        NaN  1.468857    0.019353
# 4  2.320000  2.280000   2.300000    2.300000        NaN  2.283333    0.018116
#
#    BetDSI_vig  BookMaker_vig  SportBet_vig  Bet365_vig  Bovada_vig  \
# 0    0.042390       0.054264      0.022097    0.036364    0.051282
# 1    0.042390       0.054264      0.022097    0.036364    0.051282
# 2    0.034562       0.034562      0.030776         NaN    0.055944
# 3    0.034562       0.034562      0.030776         NaN    0.055944
# 4    0.036281       0.036281      0.025373         NaN    0.052288
#
#    Sportsbook_vig  William_H_vig  Pinnacle_vig  SportsInt_vig  BetOnline_vig  \
# 0        0.049123       0.051282      0.037222       0.051020       0.033738
# 1        0.049123       0.051282      0.037222       0.051020       0.033738
# 2        0.049451            NaN      0.024244       0.059811       0.034562
# 3        0.049451            NaN      0.024244       0.059811       0.034562
# 4        0.050167            NaN      0.024530       0.055995       0.034783
#
#    Intertops_vig Winner_Cleaned   Loser_Cleaned  \
# 0       0.055172  Spike Carlyle      Aalon Cruz
# 1       0.055172  Spike Carlyle      Aalon Cruz
# 2            NaN     Matt Hobar  Aaron Phillips
# 3            NaN     Matt Hobar  Aaron Phillips
# 4            NaN    Sam Sicilia  Aaron Phillips
#
#                                             wiki_url bestfightodds_winner  \
# 0  https://en.wikipedia.org/wiki/UFC_Fight_Night:...        Spike Carlyle
# 1  https://en.wikipedia.org/wiki/UFC_Fight_Night:...        Spike Carlyle
# 2  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           Matt Hobar
# 3  https://en.wikipedia.org/wiki/UFC_Fight_Night:...           Matt Hobar
# 4              https://en.wikipedia.org/wiki/UFC_173          Sam Sicilia
#
#   bestfightodds_loser    WeightClass         Winner Outcome           Loser  \
# 0          Aalon Cruz  Featherweight  Spike Carlyle     def      Aalon Cruz
# 1          Aalon Cruz  Featherweight  Spike Carlyle     def      Aalon Cruz
# 2      Aaron Phillips   Bantamweight     Matt Hobar     def  Aaron Phillips
# 3      Aaron Phillips   Bantamweight     Matt Hobar     def  Aaron Phillips
# 4      Aaron Phillips  Featherweight    Sam Sicilia     def  Aaron Phillips
#
#                                        Method  Round  Time Notes  \
# 0                               TKO (punches)    1.0  1:25   NaN
# 1                               TKO (punches)    1.0  1:25   NaN
# 2  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
# 3  Decision (unanimous) (29–28, 29–28, 29–28)    3.0  5:00   NaN
# 4  Decision (unanimous) (29–28, 29–28, 30–27)    3.0  5:00   NaN
#
#                                 Card  \
# 0           Preliminary card (ESPN+)
# 1           Preliminary card (ESPN+)
# 2    Preliminary card (Fox Sports 2)
# 3    Preliminary card (Fox Sports 2)
# 4  Preliminary card (UFC Fight Pass)
#
#                                   Winner_url Loser_url  event_order  \
# 0                                        NaN       NaN           11
# 1                                        NaN       NaN           11
# 2   https://en.wikipedia.org/wiki/Matt_Hobar       NaN            9
# 3   https://en.wikipedia.org/wiki/Matt_Hobar       NaN            9
# 4  https://en.wikipedia.org/wiki/Sam_Sicilia       NaN           11
#
#        Method_Cleaned Card_Cleaned Champion Interim_Champion  Card_Date    #  \
# 0                  KO       Prelim      NaN              NaN 2020-02-29  511
# 1                  KO       Prelim      NaN              NaN 2020-02-29  511
# 2  Unanimous Decision       Prelim      NaN              NaN 2014-08-23  287
# 3  Unanimous Decision       Prelim      NaN              NaN 2014-08-23  287
# 4  Unanimous Decision       Prelim      NaN              NaN 2014-05-24  273
#
#                                        Event  bet_won  year
# 0  UFC Fight Night: Benavidez vs. Figueiredo        0  2020
# 1  UFC Fight Night: Benavidez vs. Figueiredo        1  2020
# 2   UFC Fight Night: Henderson vs. dos Anjos        0  2014
# 3   UFC Fight Night: Henderson vs. dos Anjos        1  2014
# 4               UFC 173: Barão vs. Dillashaw        0  2014

# %%
# convert decimal odds to probabilities using the balanced book method
betting_sites= ['5Dimes','BetDSI','BookMaker','SportBet','Bet365','Bovada', 
                'Sportsbook','William_H','Pinnacle','SportsInt','BetOnline','Intertops']

for col in betting_sites:
    bets[col+"_prob"] =  ((bets[col]**-1) - bets[col+"_vig"])/(1-bets[col+"_vig"]) 

bets["avg_prob"] = bets[[col+"_prob" for col in betting_sites]].apply("mean", axis = 1)

# %%
# how well does the average probability track actual outcomes

bins = np.arange(0,1, .05)
divided = pd.IntervalIndex.from_tuples([(bins[i], bins[i+1]) for i in np.arange(len(bins) - 1)])
consensus_group = pd.cut(bets.avg_prob, divided)
grouped = bets.groupby(consensus_group)['bet_won', 'avg_prob'].agg(avg_prob = ('avg_prob', 'mean'),
                                                                   bet_won=('bet_won', 'mean'),
                                                                      n = ('bet_won', 'size'))
grouped = grouped[grouped.bet_won.notna()]
grouped['diff'] = grouped['bet_won'] - grouped['avg_prob']
display(grouped[['avg_prob','bet_won','diff', 'n']])

fig, ax = plt.subplots()
grouped.plot.scatter(x='avg_prob', y = 'bet_won', ax = ax, label = '5% prob buckets')
x = np.linspace(0, 1, 100)
ax.plot(x, x, 'k--',label = '45 degree line')
ax.legend(loc='best')
model = smf.wls(formula='bet_won ~ avg_prob', data=grouped, weights = grouped.n).fit()
print(model.summary())
# Out:
#                                             avg_prob   bet_won      diff    n
# avg_prob
# (0.05, 0.1]                                 0.082853  0.047619 -0.035234   42
# (0.1, 0.15000000000000002]                  0.130845  0.107143 -0.023703  140
# (0.15000000000000002, 0.2]                  0.177782  0.166667 -0.011115  336
# (0.2, 0.25]                                 0.226675  0.213018 -0.013657  507
# (0.25, 0.30000000000000004]                 0.276361  0.261654 -0.014707  665
# (0.30000000000000004, 0.35000000000000003]  0.326098  0.332882  0.006784  739
# (0.35000000000000003, 0.4]                  0.376106  0.419608  0.043502  765
# (0.4, 0.45]                                 0.422837  0.457560  0.034722  754
# (0.45, 0.5]                                 0.475653  0.463596 -0.012057  673
# (0.5, 0.55]                                 0.524419  0.536513  0.012093  671
# (0.55, 0.6000000000000001]                  0.577163  0.542440 -0.034722  754
# (0.6000000000000001, 0.65]                  0.623894  0.580392 -0.043502  765
# (0.65, 0.7000000000000001]                  0.673902  0.667118 -0.006784  739
# (0.7000000000000001, 0.75]                  0.723639  0.738346  0.014707  665
# (0.75, 0.8]                                 0.773325  0.786982  0.013657  507
# (0.8, 0.8500000000000001]                   0.822218  0.833333  0.011115  336
# (0.8500000000000001, 0.9]                   0.869155  0.892857  0.023703  140
# (0.9, 0.9500000000000001]                   0.917147  0.952381  0.035234   42
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                bet_won   R-squared:                       0.983
# Model:                            WLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     949.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.13e-15
# Time:                        17:46:12   Log-Likelihood:                 38.261
# No. Observations:                  18   AIC:                            -72.52
# Df Residuals:                      16   BIC:                            -70.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0009      0.017     -0.052      0.959      -0.038       0.036
# avg_prob       1.0018      0.033     30.811      0.000       0.933       1.071
# ==============================================================================
# Omnibus:                        0.808   Durbin-Watson:                   1.118
# Prob(Omnibus):                  0.668   Jarque-Bera (JB):                0.043
# Skew:                          -0.000   Prob(JB):                        0.979
# Kurtosis:                       3.240   Cond. No.                         6.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))

# %% [markdown]
# It looks like the average probability has closely predicted the true probability with possibly a little opportunity in the 35 - 45 % probability range where underdogs seem to be winning ~4% more often than the average probabilities suggest. This seems worth investigating further. What's likely happening here is a lot of money is flowing to one side of what should be a 50 - 50 matchup, thereby making one side a better bet

# %%
# repeat analysis but look at more recent years and older years separately
# recent years 2013 - 2020
bets_recent = bets[bets.year >= 2013]
bins = np.arange(0,1, .05)
divided = pd.IntervalIndex.from_tuples([(bins[i], bins[i+1]) for i in np.arange(len(bins) - 1)])
consensus_group = pd.cut(bets_recent.avg_prob, divided)
grouped = bets_recent.groupby(consensus_group)['bet_won', 'avg_prob'].agg(avg_prob = ('avg_prob', 'mean'),
                                                                   bet_won=('bet_won', 'mean'),
                                                                      n = ('bet_won', 'size'))
grouped = grouped[grouped.bet_won.notna()]
grouped['diff'] = grouped['bet_won'] - grouped['avg_prob']
display(grouped[['avg_prob','bet_won','diff', 'n']])

fig, ax = plt.subplots()
grouped.plot.scatter(x='avg_prob', y = 'bet_won', ax = ax, label = '5% prob buckets')
x = np.linspace(0, 1, 100)
ax.plot(x, x, 'k--',label = '45 degree line')
ax.legend(loc='best')
model = smf.wls(formula='bet_won ~ avg_prob', data=grouped, weights = grouped.n).fit()
print(model.summary())
# Out:
#                                             avg_prob   bet_won      diff    n
# avg_prob
# (0.05, 0.1]                                 0.082984  0.050000 -0.032984   40
# (0.1, 0.15000000000000002]                  0.130285  0.115044 -0.015241  113
# (0.15000000000000002, 0.2]                  0.176919  0.157025 -0.019894  242
# (0.2, 0.25]                                 0.227397  0.211940 -0.015457  335
# (0.25, 0.30000000000000004]                 0.276686  0.247748 -0.028938  444
# (0.30000000000000004, 0.35000000000000003]  0.325810  0.331301  0.005490  492
# (0.35000000000000003, 0.4]                  0.376810  0.436945  0.060135  563
# (0.4, 0.45]                                 0.423088  0.463497  0.040409  589
# (0.45, 0.5]                                 0.475704  0.465887 -0.009817  513
# (0.5, 0.55]                                 0.524391  0.534247  0.009855  511
# (0.55, 0.6000000000000001]                  0.576912  0.536503 -0.040409  589
# (0.6000000000000001, 0.65]                  0.623190  0.563055 -0.060135  563
# (0.65, 0.7000000000000001]                  0.674190  0.668699 -0.005490  492
# (0.7000000000000001, 0.75]                  0.723314  0.752252  0.028938  444
# (0.75, 0.8]                                 0.772603  0.788060  0.015457  335
# (0.8, 0.8500000000000001]                   0.823081  0.842975  0.019894  242
# (0.8500000000000001, 0.9]                   0.869715  0.884956  0.015241  113
# (0.9, 0.9500000000000001]                   0.917016  0.950000  0.032984   40
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                bet_won   R-squared:                       0.971
# Model:                            WLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     536.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           9.81e-14
# Time:                        17:46:15   Log-Likelihood:                 33.482
# No. Observations:                  18   AIC:                            -62.96
# Df Residuals:                      16   BIC:                            -61.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0028      0.023     -0.119      0.907      -0.052       0.046
# avg_prob       1.0055      0.043     23.168      0.000       0.914       1.098
# ==============================================================================
# Omnibus:                        1.573   Durbin-Watson:                   1.120
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                0.287
# Skew:                          -0.000   Prob(JB):                        0.866
# Kurtosis:                       3.618   Cond. No.                         6.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# repeat analysis but look at older years separately (2008 - 2012)

bets_recent = bets[bets.year < 2013]
bins = np.arange(0,1, .05)
divided = pd.IntervalIndex.from_tuples([(bins[i], bins[i+1]) for i in np.arange(len(bins) - 1)])
consensus_group = pd.cut(bets_recent.avg_prob, divided)
grouped = bets_recent.groupby(consensus_group)['bet_won', 'avg_prob'].agg(avg_prob = ('avg_prob', 'mean'),
                                                                   bet_won=('bet_won', 'mean'),
                                                                      n = ('bet_won', 'size'))
grouped = grouped[grouped.bet_won.notna()]
grouped['diff'] = grouped['bet_won'] - grouped['avg_prob']
display(grouped[['avg_prob','bet_won','diff', 'n']])

fig, ax = plt.subplots()
grouped.plot.scatter(x='avg_prob', y = 'bet_won', ax = ax, label = "5% buckets")
x = np.linspace(0, 1, 100)
ax.plot(x, x, 'k--',label = '45 degree line')
ax.legend(loc='best')
model = smf.wls(formula='bet_won ~ avg_prob', data=grouped, weights = grouped.n).fit()
print(model.summary())
# Out:
#                                             avg_prob   bet_won      diff    n
# avg_prob
# (0.05, 0.1]                                 0.080233  0.000000 -0.080233    2
# (0.1, 0.15000000000000002]                  0.133191  0.074074 -0.059116   27
# (0.15000000000000002, 0.2]                  0.180005  0.191489  0.011485   94
# (0.2, 0.25]                                 0.225269  0.215116 -0.010153  172
# (0.25, 0.30000000000000004]                 0.275707  0.289593  0.013885  221
# (0.30000000000000004, 0.35000000000000003]  0.326672  0.336032  0.009360  247
# (0.35000000000000003, 0.4]                  0.374143  0.371287 -0.002856  202
# (0.4, 0.45]                                 0.421941  0.436364  0.014422  165
# (0.45, 0.5]                                 0.475490  0.456250 -0.019240  160
# (0.5, 0.55]                                 0.524510  0.543750  0.019240  160
# (0.55, 0.6000000000000001]                  0.578059  0.563636 -0.014422  165
# (0.6000000000000001, 0.65]                  0.625857  0.628713  0.002856  202
# (0.65, 0.7000000000000001]                  0.673328  0.663968 -0.009360  247
# (0.7000000000000001, 0.75]                  0.724293  0.710407 -0.013885  221
# (0.75, 0.8]                                 0.774731  0.784884  0.010153  172
# (0.8, 0.8500000000000001]                   0.819995  0.808511 -0.011485   94
# (0.8500000000000001, 0.9]                   0.866809  0.925926  0.059116   27
# (0.9, 0.9500000000000001]                   0.919767  1.000000  0.080233    2
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                bet_won   R-squared:                       0.994
# Model:                            WLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     2649.
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.32e-19
# Time:                        17:46:21   Log-Likelihood:                 45.314
# No. Observations:                  18   AIC:                            -86.63
# Df Residuals:                      16   BIC:                            -84.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0034      0.010      0.331      0.745      -0.019       0.025
# avg_prob       0.9931      0.019     51.469      0.000       0.952       1.034
# ==============================================================================
# Omnibus:                        2.297   Durbin-Watson:                   2.639
# Prob(Omnibus):                  0.317   Jarque-Bera (JB):                1.059
# Skew:                           0.000   Prob(JB):                        0.589
# Kurtosis:                       1.812   Cond. No.                         6.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# It looks like the overperformance of fighters in the 35% - 45% range
# is a phenomena that's only occured since 2013
# let's investigate this further

bets_recent = bets[(bets.year >= 2013)& (bets.avg_prob >= .3) & (bets.avg_prob <= .5)].copy()
fig, ax = plt.subplots()
sns.regplot('avg_prob', 'bet_won', data = bets_recent, scatter = False, lowess = True, ax = ax, label = 'Lowess')
x = np.linspace(.3, .5, 100)
ax.plot(x, x, 'k--',label = '45 degree line')
ax.set_xticks(np.arange(.3,.51,.01))
ax.set_xticklabels([round(x,2) if i%5 == 0 else '' for i, x in enumerate(np.arange(.3,.51,.01))])
ax.legend(loc='best')

# %% [markdown]
# It looks like fighters in the 37% - 42% range did very well from 2013 - 2020

# %%
## how have vigs changed over time

fig1, ax1 = plt.subplots()
yeargroup = bets.groupby('year')
for col in betting_sites:
     s = yeargroup.agg(avg_vig= (col+'_vig', 'mean')).reset_index()
     ax1.plot(s.year,s.avg_vig, label = col)
ax1.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# Looks like Vigs have gone down accross most betting sites over time, but there are still a decent amount of high vig sites

# %%
# how do results change if I use probability from betting site with lowest vig for each fight
# rather than the average probability?

bets["lowest_vig"] = bets[[col+"_vig" for col in betting_sites]].apply(pd.Series.idxmin, axis = 1)
print(bets["lowest_vig"].value_counts())
bets["lowest_vig_prob"] = bets.lookup(bets.index, bets["lowest_vig"].apply(lambda x: x[0:-3]+"prob"))
# Out:
# 5Dimes_vig        6400
# Pinnacle_vig      2044
# SportBet_vig       708
# BookMaker_vig       64
# Sportsbook_vig      16
# Bovada_vig           6
# BetDSI_vig           2
# Name: lowest_vig, dtype: int64

# %%
# how well does the lowest vig probability track actual outcomes

bins = np.arange(0,1, .05)
divided = pd.IntervalIndex.from_tuples([(bins[i], bins[i+1]) for i in np.arange(len(bins) - 1)])
consensus_group = pd.cut(bets.avg_prob, divided)
grouped = bets.groupby(consensus_group)['bet_won', "lowest_vig_prob"].agg(avg_lowest_vig_prob = ('lowest_vig_prob', 'mean'),
                                                                   bet_won=('bet_won', 'mean'),
                                                                      n = ('bet_won', 'size'))
grouped = grouped[grouped.bet_won.notna()]
grouped['diff'] = grouped['bet_won'] - grouped['avg_lowest_vig_prob']
display(grouped[['avg_lowest_vig_prob','bet_won','diff', 'n']])

fig, ax = plt.subplots()
grouped.plot.scatter(x='avg_lowest_vig_prob', y = 'bet_won', ax = ax, label = "5% buckets")
x = np.linspace(0, 1, 100)
ax.plot(x, x, 'k--', label = '45 degree line')
ax.legend(loc='best')
model = smf.wls(formula='bet_won ~ avg_lowest_vig_prob', data=grouped, weights = grouped.n).fit()
print(model.summary())
# Out:
#                                             avg_lowest_vig_prob   bet_won  \
# avg_prob
# (0.05, 0.1]                                            0.086626  0.047619
# (0.1, 0.15000000000000002]                             0.133531  0.107143
# (0.15000000000000002, 0.2]                             0.182196  0.166667
# (0.2, 0.25]                                            0.231919  0.213018
# (0.25, 0.30000000000000004]                            0.280772  0.261654
# (0.30000000000000004, 0.35000000000000003]             0.329894  0.332882
# (0.35000000000000003, 0.4]                             0.378453  0.419608
# (0.4, 0.45]                                            0.423617  0.457560
# (0.45, 0.5]                                            0.474713  0.463596
# (0.5, 0.55]                                            0.525362  0.536513
# (0.55, 0.6000000000000001]                             0.576383  0.542440
# (0.6000000000000001, 0.65]                             0.621547  0.580392
# (0.65, 0.7000000000000001]                             0.670106  0.667118
# (0.7000000000000001, 0.75]                             0.719228  0.738346
# (0.75, 0.8]                                            0.768081  0.786982
# (0.8, 0.8500000000000001]                              0.817804  0.833333
# (0.8500000000000001, 0.9]                              0.866469  0.892857
# (0.9, 0.9500000000000001]                              0.913374  0.952381
#
#                                                 diff    n
# avg_prob
# (0.05, 0.1]                                -0.039007   42
# (0.1, 0.15000000000000002]                 -0.026388  140
# (0.15000000000000002, 0.2]                 -0.015530  336
# (0.2, 0.25]                                -0.018901  507
# (0.25, 0.30000000000000004]                -0.019118  665
# (0.30000000000000004, 0.35000000000000003]  0.002989  739
# (0.35000000000000003, 0.4]                  0.041155  765
# (0.4, 0.45]                                 0.033943  754
# (0.45, 0.5]                                -0.011117  673
# (0.5, 0.55]                                 0.011151  671
# (0.55, 0.6000000000000001]                 -0.033943  754
# (0.6000000000000001, 0.65]                 -0.041155  765
# (0.65, 0.7000000000000001]                 -0.002989  739
# (0.7000000000000001, 0.75]                  0.019118  665
# (0.75, 0.8]                                 0.018901  507
# (0.8, 0.8500000000000001]                   0.015530  336
# (0.8500000000000001, 0.9]                   0.026388  140
# (0.9, 0.9500000000000001]                   0.039007   42
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                bet_won   R-squared:                       0.984
# Model:                            WLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     961.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.02e-15
# Time:                        17:48:15   Log-Likelihood:                 38.370
# No. Observations:                  18   AIC:                            -72.74
# Df Residuals:                      16   BIC:                            -70.96
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0093      0.018     -0.528      0.605      -0.047       0.028
# avg_lowest_vig_prob     1.0186      0.033     31.003      0.000       0.949       1.088
# ==============================================================================
# Omnibus:                        0.931   Durbin-Watson:                   1.106
# Prob(Omnibus):                  0.628   Jarque-Bera (JB):                0.070
# Skew:                          -0.000   Prob(JB):                        0.966
# Kurtosis:                       3.305   Cond. No.                         6.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# compare log loss of simple average versus lowest vig probability

print(np.mean(-np.log(bets[bets.bet_won == 1]['avg_prob'])))
print(np.mean(-np.log(bets[bets.bet_won == 1]["lowest_vig_prob"])))

# on average assigning a 54% win chance to the winning side
print(np.exp(-np.mean(-np.log(bets[bets.bet_won == 1]['avg_prob']))))
print(np.exp(-np.mean(-np.log(bets[bets.bet_won == 1]['lowest_vig_prob']))))


# compare brier score of simple average versus lowest vig probability

print(np.mean((1 - bets[bets.bet_won == 1]['avg_prob'])**2))
print(np.mean((1 - bets[bets.bet_won == 1]['lowest_vig_prob'])**2))
# Out:
# 0.6129427637823484
# 0.613142360910794
# 0.5417542661806614
# 0.5416461443755684
# 0.21264426496661923
# 0.21270026772241665

# %%
# how much variation is there in vig adjusted probabilities accross the betting sites

bets["max_prob"] = bets[[col+"_prob" for col in betting_sites]].apply("max", axis = 1)
bets["min_prob"] = bets[[col+"_prob" for col in betting_sites]].apply("min", axis = 1)
bets["max_pct_diff"] = np.abs(bets["max_prob"]/bets["avg_prob"] - 1)
bets["min_pct_diff"] = np.abs(bets["min_prob"]/bets["avg_prob"] - 1)
bets["biggest_pct_diff"] = bets[["min_pct_diff", "max_pct_diff"]].apply("max", axis = 1)
sns.distplot(bets["biggest_pct_diff"])
bets["biggest_pct_diff"].describe()
# Out:
# count    9240.000000
# mean        0.053968
# std         0.043402
# min         0.000000
# 25%         0.027570
# 50%         0.042309
# 75%         0.066171
# max         0.648740
# Name: biggest_pct_diff, dtype: float64

# %% [markdown]
# It looks like the probabilities accross sites track eachother closely/tend to be very close to the average probability (~5 percent (percent, not percentage points) above or below the average probability). After accounting for the vig, it doesn't look like there is enough price outliers to make a profit based on odds mispricing.

# %% [markdown]
# # Investigate Betting Strategy Based on Mispricing Opportunities

# %%
# bet only if pd -1 >= r to earn expected value of at least r dollars
# first try using the average probability accross sites
# assuming I always bet at best odds avaiable

bets['best_odds'] = bets[betting_sites].apply("max", axis = 1)
bets['return'] = np.where(bets['bet_won'] == 1, bets['best_odds'] -1, -1)
bets["best_odds_site"] = bets[[col for col in betting_sites]].apply(pd.Series.idxmax, axis = 1)
bets['breakeven_prob'] = 1/bets['best_odds']
bets["best_odds_vig"] = bets['breakeven_prob'] - bets.lookup(bets.index, bets["best_odds_site"].apply(lambda x: x+"_prob"))
print(bets["best_odds_vig"].describe())
# Out:
# count    9240.000000
# mean        0.015995
# std         0.010313
# min         0.001127
# 25%         0.009130
# 50%         0.013032
# 75%         0.019579
# max         0.073556
# Name: best_odds_vig, dtype: float64

# %%
def get_return(df, r, prob_col):
    df['pd_minus1'] = df['best_odds']*df[prob_col] - 1
    num_fights = df.groupby('year').agg(total_fights = ('pd_minus1', lambda x: x.size/2)).reset_index()
    df = df[df['pd_minus1'] >= r].copy()

    out = df.groupby('year').agg(num_bets = ('pd_minus1', "size"),
                           avg_odds = ('best_odds', "mean"),
                           avg_breakeven_prob = ('breakeven_prob', "mean"),
                           pct_won = ('bet_won', "mean"),
                           avg_estimated_vig = ('best_odds_vig', "mean"),
                           avg_return = ('return', "mean"),
                           std_return = ('return', 'std')
                          ).reset_index()
    out = pd.merge(num_fights, out, on = 'year')
    out['% fights bet'] = out['num_bets']/out['total_fights']
    return out[['year', 'total_fights', 'num_bets', '% fights bet', 'avg_odds', 
                'avg_breakeven_prob', 'pct_won','avg_estimated_vig', 'avg_return', 'std_return']]

# %%
## try betting based on mispricing using the average probability

for r in [.01, .02, .03, .04, .05, .06]:
    print("r = "+str(r))
    display(get_return(bets, r, 'avg_prob'))
# Out:
# r = 0.01
#     year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0   2008         200.0        87      0.435000  1.635352            0.657247
# 1   2009         212.0        77      0.363208  1.712354            0.627750
# 2   2010         250.0        70      0.280000  1.495015            0.692628
# 3   2011         295.0        68      0.230508  1.419033            0.716269
# 4   2012         333.0        89      0.267267  1.605958            0.657023
# 5   2013         376.0        78      0.207447  1.559864            0.669332
# 6   2014         493.0        95      0.192698  1.591439            0.660167
# 7   2015         464.0        97      0.209052  1.735301            0.643213
# 8   2016         482.0        94      0.195021  1.597412            0.659823
# 9   2017         445.0       119      0.267416  1.681360            0.635438
# 10  2018         471.0       175      0.371550  1.744352            0.620187
# 11  2019         507.0        98      0.193294  1.742533            0.615911
# 12  2020          92.0        16      0.173913  1.372296            0.748087
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.701149           0.011223    0.068936    0.769768
# 1   0.584416           0.014863   -0.043379    0.899509
# 2   0.671429           0.009634   -0.043781    0.706843
# 3   0.720588           0.008807   -0.001285    0.642068
# 4   0.584270           0.015340   -0.128948    0.773305
# 5   0.653846           0.012380   -0.047933    0.728700
# 6   0.673684           0.012568    0.015685    0.774763
# 7   0.680412           0.015671    0.068270    0.841330
# 8   0.648936           0.016338   -0.005255    0.810454
# 9   0.647059           0.014975    0.009243    0.810019
# 10  0.674286           0.016893    0.076755    0.838451
# 11  0.612245           0.016742   -0.004498    0.898989
# 12  0.750000           0.013234    0.034852    0.658970
# r = 0.02
#     year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0   2008         200.0        32      0.160000  1.851907            0.604131
# 1   2009         212.0        27      0.127358  1.752342            0.617958
# 2   2010         250.0        24      0.096000  1.471409            0.696700
# 3   2011         295.0        23      0.077966  1.431476            0.709056
# 4   2012         333.0        24      0.072072  1.879726            0.570563
# 5   2013         376.0        22      0.058511  1.654798            0.630099
# 6   2014         493.0        17      0.034483  1.888927            0.558928
# 7   2015         464.0        36      0.077586  2.024119            0.557345
# 8   2016         482.0        32      0.066390  1.734434            0.620551
# 9   2017         445.0        44      0.098876  1.814827            0.602824
# 10  2018         471.0        79      0.167728  1.930271            0.570068
# 11  2019         507.0        31      0.061144  1.911214            0.570470
# 12  2020          92.0         4      0.043478  1.405404            0.725449
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.593750           0.012661   -0.040443    0.885886
# 1   0.592593           0.013155   -0.048928    0.861321
# 2   0.625000           0.007813   -0.121193    0.711300
# 3   0.782609           0.010053    0.089735    0.600215
# 4   0.458333           0.020319   -0.187532    0.952790
# 5   0.727273           0.016665    0.131442    0.753604
# 6   0.529412           0.022396    0.066534    1.113031
# 7   0.722222           0.022844    0.307411    0.977193
# 8   0.593750           0.021381    0.013473    0.968179
# 9   0.613636           0.019698    0.022976    0.906077
# 2   2012         333.0         3      0.009009  2.615054            0.423412
# 3   2013         376.0         1      0.002660  1.571429            0.636364
# 4   2014         493.0         1      0.002028  1.746269            0.572650
# 5   2015         464.0         5      0.010776  2.542476            0.414209
# 6   2016         482.0         5      0.010373  2.095328            0.499366
# 7   2017         445.0         6      0.013483  2.201608            0.502622
# 8   2018         471.0        20      0.042463  2.599925            0.423161
# 9   2019         507.0         3      0.005917  2.966667            0.361803
# 10  2020          92.0         1      0.010870  1.571429            0.636364
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.500000           0.024930    0.275000    1.803122
# 1   1.000000           0.032303    1.150000         NaN
# 2   0.000000           0.031105   -1.000000    0.000000
# 3   1.000000           0.016946    0.571429         NaN
# 4   1.000000           0.011020    0.746269         NaN
# 5   0.600000           0.032559    0.612476    1.622397
# 6   0.600000           0.033554    0.241481    1.218767
# 7   0.333333           0.025300   -0.322947    1.130974
# 8   0.500000           0.027415    0.199092    1.363206
# 9   0.666667           0.024918    1.216667    2.089458
# 10  1.000000           0.027853    0.571429         NaN
# r = 0.06
#    year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0  2008         200.0         2      0.010000  2.665000            0.375935
# 1  2012         333.0         2      0.006006  2.122581            0.496229
# 2  2014         493.0         1      0.002028  1.746269            0.572650
# 3  2015         464.0         4      0.008621  2.690000            0.389713
# 4  2016         482.0         2      0.004149  2.284615            0.461180
# 5  2017         445.0         5      0.011236  2.369465            0.456338
# 6  2018         471.0        14      0.029724  2.614179            0.434648
# 7  2019         507.0         3      0.005917  2.966667            0.361803
# 8  2020          92.0         1      0.010870  1.571429            0.636364
#
#     pct_won  avg_estimated_vig  avg_return  std_return
# 0  0.500000           0.024930    0.275000    1.803122
# 1  0.000000           0.027450   -1.000000    0.000000
# 2  1.000000           0.011020    0.746269         NaN
# 3  0.500000           0.031836    0.527500    1.860491
# 4  0.500000           0.036788    0.400000    1.979899
# 5  0.200000           0.028098   -0.460000    1.207477
# 6  0.500000           0.027437    0.152274    1.367871
# 7  0.666667           0.024918    1.216667    2.089458
# 8  1.000000           0.027853    0.571429         NaN

# %%
## try betting based on mispricing using the probability from the betting site with the lowest vig

for r in [.01, .02, .03, .04, .05, .06]:
    print("r = "+str(r))
    display(get_return(bets, r, "lowest_vig_prob"))
# Out:
# r = 0.01
#     year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0   2008         200.0        63      0.315000  1.879548            0.592542
# 1   2009         212.0        76      0.358491  2.133147            0.530588
# 2   2010         250.0        61      0.244000  2.290294            0.505805
# 3   2011         295.0        43      0.145763  2.107626            0.539829
# 4   2012         333.0        99      0.297297  2.006534            0.559948
# 5   2013         376.0        76      0.202128  1.942570            0.568770
# 6   2014         493.0        88      0.178499  2.103574            0.554721
# 7   2015         464.0        98      0.211207  1.942393            0.581779
# 8   2016         482.0       129      0.267635  1.812223            0.602917
# 9   2017         445.0       124      0.278652  1.884420            0.597134
# 10  2018         471.0       147      0.312102  2.055875            0.538648
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.600000           0.033218    0.680000    1.563889
# 1   0.571429           0.034359    0.120446    1.054884
# 2   0.500000           0.031894   -0.034632    1.114851
# 3   0.000000           0.047118   -1.000000    0.000000
# 4   0.142857           0.031001   -0.628571    0.982708
# 5   0.333333           0.027596   -0.476190    0.907265
# 6   0.666667           0.036101    0.531045    1.292089
# 7   0.666667           0.030416    0.496843    1.278220
# 8   0.600000           0.034878    0.322248    1.198138
# 9   0.473684           0.030281    0.033740    1.179958
# 10  0.419355           0.032813   -0.028443    1.236422
# 11  0.222222           0.029248   -0.222222    1.622327
# 12  1.000000           0.027853    0.571429         NaN
# r = 0.06
#     year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0   2008         200.0         5      0.025000  3.080000            0.341913
# 1   2009         212.0         6      0.028302  2.342857            0.458103
# 2   2010         250.0         1      0.004000  3.350000            0.298507
# 3   2011         295.0         1      0.003390  5.000000            0.200000
# 4   2012         333.0         6      0.018018  2.342281            0.460604
# 5   2013         376.0         2      0.005319  2.485714            0.465241
# 6   2014         493.0         4      0.008114  2.241458            0.469885
# 7   2015         464.0         7      0.015086  2.266016            0.479760
# 8   2016         482.0         9      0.018672  2.471763            0.446254
# 9   2017         445.0        13      0.029213  2.742416            0.414158
# 10  2018         471.0        25      0.053079  2.629132            0.414118
# 11  2019         507.0         6      0.011834  2.520866            0.417617
# 12  2020          92.0         1      0.010870  1.571429            0.636364
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.600000           0.033218    0.680000    1.563889
# 1   0.500000           0.035376    0.017063    1.116045
# 2   0.000000           0.033318   -1.000000         NaN
# 3   0.000000           0.048485   -1.000000         NaN
# 4   0.166667           0.031449   -0.566667    1.061446
# 5   0.500000           0.024763   -0.214286    1.111168
# 6   0.500000           0.032692    0.224067    1.525188
# 7   0.714286           0.027884    0.601731    1.329002
# 8   0.444444           0.036993    0.050823    1.335683
# 9   0.538462           0.028806    0.258640    1.268091
# 10  0.400000           0.033665   -0.049393    1.264615
# 11  0.166667           0.028830   -0.583333    1.020621
# 12  1.000000           0.027853    0.571429         NaN

# %% [markdown]
# # Investigate Betting Strategy Based On Betting On Fighters with Avg Probability of Winning = 37% - 42%

# %%
def get_return_based_on_prob_range(df, prob_col, prob_min, prob_max):
    num_fights = df.groupby('year').agg(total_fights = ('pd_minus1', lambda x: x.size/2)).reset_index()
    df = df[(df[prob_col] >= prob_min) & (df[prob_col] <= prob_max)].copy()
    df['breakeven_prob'] = 1/df['best_odds']
    out = df.groupby('year').agg(num_bets = ('pd_minus1', "size"),
                           avg_odds = ('best_odds', "mean"),
                           avg_breakeven_prob = ('breakeven_prob', "mean"),
                           pct_won = ('bet_won', "mean"),
                           avg_estimated_vig = ('best_odds_vig', "mean"),
                           avg_return = ('return', "mean"),
                           std_return = ('return', 'std')
                          ).reset_index()
    out = pd.merge(num_fights, out, on = 'year')
    out['% fights bet'] = out['num_bets']/out['total_fights']
    return out[['year', 'total_fights', 'num_bets', '% fights bet', 'avg_odds', 
                'avg_breakeven_prob', 'pct_won', 'avg_estimated_vig', 'avg_return', 'std_return']]
print('bets with avg vig adjusted probability in the .37 to .42 range')
display(get_return_based_on_prob_range(bets, 'avg_prob', .37, .42))
# Out:
# bets with avg vig adjusted probability in the .37 to .42 range
#     year  total_fights  num_bets  % fights bet  avg_odds  avg_breakeven_prob  \
# 0   2008         200.0        32      0.160000  2.490000            0.402275
# 1   2009         212.0        25      0.117925  2.484800            0.403037
# 2   2010         250.0        42      0.168000  2.489524            0.402350
# 3   2011         295.0        41      0.138983  2.467317            0.405825
# 4   2012         333.0        49      0.147147  2.475102            0.404521
# 5   2013         376.0        59      0.156915  2.496610            0.401020
# 6   2014         493.0        81      0.164300  2.476049            0.404382
# 7   2015         464.0        80      0.172414  2.494875            0.401420
# 8   2016         482.0       101      0.209544  2.477129            0.404305
# 9   2017         445.0        78      0.175281  2.487051            0.402755
# 10  2018         471.0       107      0.227176  2.493551            0.401716
# 11  2019         507.0       110      0.216963  2.499727            0.401626
# 12  2020          92.0        18      0.195652  2.480000            0.403991
#
#      pct_won  avg_estimated_vig  avg_return  std_return
# 0   0.406250           0.019106    0.008125    1.239496
# 1   0.320000           0.016586   -0.209200    1.178544
# 2   0.404762           0.020174    0.000952    1.230211
# 3   0.317073           0.016853   -0.226585    1.149971
# 4   0.326531           0.022704   -0.195102    1.168792
# 5   0.440678           0.018903    0.092542    1.243030
# 6   0.419753           0.016902    0.040494    1.232042
# 7   0.487500           0.016182    0.220000    1.260608
# 8   0.524752           0.016423    0.303267    1.248747
# 9   0.435897           0.018105    0.085385    1.244707
# 10  0.476636           0.018129    0.187570    1.252074
# 11  0.436364           0.015542    0.093636    1.259942
# 12  0.444444           0.010539    0.094444    1.261289

# %% [markdown]
# # Use Simulation to Determine How Accurate Avg_Prob is as Predictor of True Probability

# %%
def log_loss(p, y):
    return -np.mean(y*np.log(p)+(1-y)*np.log(1 - p))

def brier(p, y):
    return np.mean(y*(1 - p)**2 + (1-y)*(p**2))

winning_probs = bets.loc[bets['bet_won'] == 1, "avg_prob"]
print(len(winning_probs))
sim = 1000
df = pd.DataFrame()
df['brier'] = np.repeat(np.nan, sim)
df['log_loss'] = np.nan
numpy.random.seed(22)
for k in range(sim):
    y = np.random.binomial(1, winning_probs)
    df['brier'].iloc[k] = brier(winning_probs, y)
    df['log_loss'].iloc[k] =log_loss(winning_probs, y)
print(df.describe())   

print(-np.mean(np.log(bets[bets.bet_won == 1]['avg_prob'])))
print(np.mean((1 - bets[bets.bet_won == 1]['avg_prob'])**2))
# Out:
# 4620
#              brier     log_loss
# count  1000.000000  1000.000000
# mean      0.212728     0.613977
# std       0.002419     0.005405
# min       0.206530     0.599728
# 25%       0.211010     0.610183
# 50%       0.212639     0.613797
# 75%       0.214322     0.617538
# max       0.220540     0.630765
# 0.6129427637823484
# 0.21264426496661923

# %% [markdown]
# It doesn't seem worth it/posible to come up with a better forecaster than the average probability.
